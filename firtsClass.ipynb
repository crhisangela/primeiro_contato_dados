# %% [markdown]
# ## Imports

# %%
import pandas as pd

url = 'https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv'

dados = pd.read_csv(url)

# %% [markdown]
# ## Conhecendo meus dados

# %%
dados    # mostra o número de linhas e colunas (resumo)
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10006         Rua Manuel Onha, , 514        Vila Oratório  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas  \
# 0          1000        4          8      6
# 1           496        4          4      4
# ...

# %%
dados.head()    #acessa as primeiras n linhas
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.sample(10)   # retorna uma selecao aleatoria de linhas na quantidade escolhida
# Out:
#                                  Rua                          Bairro  \
# 126                     Rua Cautaros                        Itaquera
# 4763       Rua Marquês de Herval, 0                    Vila da Saúde
# 5049              Rua Perucaba, 153                          Tatuapé
# 4978                   Rua Argentina                  Jardim América
# 452                 Avenida Amarilis                   Cidade Jardim
# 1574                             NaN                  Granja Julieta
# 9606            Rua dos Comerciários                   Cidade Vargas
# 8358  Rua São Pedro do Jequitinhonha  Jardim São Carlos (Zona Leste)
# 9844                Rua Stela Marina               Brooklin Paulista
# 6847                             NaN                  Jardim Cidália
#
#          Cidade  Metragem  Quartos  Banheiros  Vagas  \
# 126   São Paulo       185        3          5      5
# 4763  São Paulo        90        2          2      1
# ...

# %%
dados.info()     # informação dos dados (str, int, etc)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
#dados.Bairro   # outra maneira de puxar só X coluna
dados["Bairro"]
# Out:
# 0         Planalto Paulista
# 1        Jardim dos Estados
# 2           Jardim Reimberg
# 3            Jardim Morumbi
# 4                     Mooca
#                 ...
# 10003            Vila Sofia
# 10004       Bosque da Saúde
# 10005         Vila da Saúde
# 10006         Vila Oratório
# 10007           Vila Alpina
# Name: Bairro, Length: 10008, dtype: object

# %%
#dados.Metragem.mean()   #média da coluna X que é int

dados["Metragem"].mean()  #achando média de colunas com nomes ruins
# Out:
# 442.30065947242207

# %% [markdown]
# ## QUANTOS IMOVEIS EU TENHO NA VILA MARIANA??

# %%
tem_imoveis_vila_mariana = (dados["Bairro"] == "Vila Mariana")        #onde tem imovel vila mariana
qtde_imoveis_vila_mariana = sum(dados["Bairro"] == "Vila Mariana")  #quantos imoveis tem na vila mariana

imoveis_vila_mariana = dados[tem_imoveis_vila_mariana]   

 #quantidade de imoveis por bairro
numero_imoveis_bairro = dados["Bairro"].value_counts()   
numero_imoveis_bairro.head(10).plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # EXERCÍCIOS

# %% [markdown]
# ## 1- Realizar a média da metragem para cara um dos bairros

# %%
dados.groupby("Bairro")["Metragem"].mean()
# Out:
# Bairro
# Aclimação            253.056818
# Alto da Boa Vista    418.875000
# Alto da Lapa         294.337209
# Alto da Mooca        270.050000
# Alto de Pinheiros    433.444988
#                         ...
# Vila Água Funda      152.200000
# Água Branca          191.000000
# Água Fria            165.416667
# Água Funda           139.000000
# Água Rasa            340.250000
# Name: Metragem, Length: 701, dtype: float64

# %%
dados.groupby("Bairro")["Metragem"].describe()
# Out:
#                    count        mean         std    min     25%    50%  \
# Bairro
# Aclimação           88.0  253.056818  159.140245  104.0  165.00  227.5
# Alto da Boa Vista    8.0  418.875000  111.880596  315.0  347.50  378.0
# Alto da Lapa        86.0  294.337209  187.674036   46.0  151.25  255.0
# Alto da Mooca       20.0  270.050000  237.306924   84.0  133.75  182.5
# Alto de Pinheiros  409.0  433.444988  145.676574  100.0  344.00  412.0
# ...                  ...         ...         ...    ...     ...    ...
# Vila Água Funda      5.0  152.200000   44.353128   90.0  138.00  143.0
# Água Branca         13.0  191.000000   91.045776   91.0  143.00  174.0
# Água Fria           12.0  165.416667   82.934211   60.0   76.25  174.5
# Água Funda           2.0  139.000000   19.798990  125.0  132.00  139.0
# Água Rasa            8.0  340.250000  294.046036   86.0  172.50  180.0
#
#                       75%     max
# Bairro
# Aclimação          300.00  1500.0
# ...

# %% [markdown]
# ## 2- formas de selecionar os dados por bairro

# %%
dados[dados["Bairro"] == "Vila Madalena"]
# Out:
#                                Rua         Bairro     Cidade  Metragem  \
# 23             Rua Aldo de Azevedo  Vila Madalena  São Paulo       170
# 39    Rua Gregório Paes de Almeida  Vila Madalena  São Paulo       401
# 119                Rua dos Tamanás  Vila Madalena  São Paulo       440
# 138                            NaN  Vila Madalena  São Paulo       534
# 167                     Rua Judith  Vila Madalena  São Paulo       146
# ...                            ...            ...        ...       ...
# 9326                Rua Alvilândia  Vila Madalena  São Paulo       380
# 9396      Rua Professor Nova Gomes  Vila Madalena  São Paulo       407
# 9484                           NaN  Vila Madalena  São Paulo       385
# 9626                           NaN  Vila Madalena  São Paulo       385
# 9649                   Rua Caraúna  Vila Madalena  São Paulo       632
#
#       Quartos  Banheiros  Vagas         Valor
# 23          2          2      1  R$ 1.485.000
# ...

# %%
dados["Bairro"][33]   #Linha 33 de bairro
# Out:
# 'Cidade Domitila'

# %% [markdown]
# ## 3- Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão

# %%
dados[['Bairro','Quartos', 'Banheiros']].head(10).groupby('Bairro').max().plot.bar()
# Out:
# <AxesSubplot:xlabel='Bairro'>

# %% [markdown]
# ## 4- Pegar outras estatísticas dos dados, média, mediana, mim, max

# %%
dados["Metragem"].mean() , dados["Metragem"].median() , dados["Metragem"].max() , dados["Metragem"].min()
# Out:
# (442.30065947242207, 290.0, 750000, 10)

# %%
dados["Metragem"].describe()
# Out:
# count     10008.000000
# mean        442.300659
# std        7515.379389
# min          10.000000
# 25%         173.000000
# 50%         290.000000
# 75%         460.250000
# max      750000.000000
# Name: Metragem, dtype: float64

# %% [markdown]
# ## 5 - Descobrir quais são os bairros que não tem nome de Rua.

# %%
dados[dados["Rua"].isna()].describe()   #informação sobre valores vazios (NaN)
# Out:
#            Metragem      Quartos    Banheiros        Vagas
# count   3434.000000  3434.000000  3434.000000  3434.000000
# mean     415.965929     3.580664     4.110367     4.514269
# std      660.586487     1.059290     2.210926     3.137578
# min       35.000000     1.000000     1.000000     1.000000
# 25%      198.000000     3.000000     3.000000     3.000000
# 50%      353.000000     4.000000     4.000000     4.000000
# 75%      539.750000     4.000000     5.000000     6.000000
# max    35677.000000    13.000000    40.000000    42.000000
